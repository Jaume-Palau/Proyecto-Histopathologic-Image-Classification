# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

# %%
sys.path
# Out:
# ['/home/jaume/miniconda3/envs/histopathologic/lib/python311.zip',
#  '/home/jaume/miniconda3/envs/histopathologic/lib/python3.11',
#  '/home/jaume/miniconda3/envs/histopathologic/lib/python3.11/lib-dynload',
#  '',
#  '/home/jaume/miniconda3/envs/histopathologic/lib/python3.11/site-packages',
#  '/mnt/ssd/Programacion/histopathologic_project']

# %%
import pandas as pd

from src.config import TRAIN_LABELS_CSV


df_labels = pd.read_csv(TRAIN_LABELS_CSV)

# %%
df_labels.head()
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0
